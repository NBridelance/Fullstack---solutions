# %% [markdown]
# # Projet d'implementation de YoloV3
#
# [Repo Github](https://github.com/zzh8829/yolov3-tf2)

# %%
# !unzip yolov3-tf2-master.zip
# Out:
# Archive:  yolov3-tf2-master.zip
# e5130786a33dcc612e2617949616defff34237c0
#    creating: yolov3-tf2-master/
#   inflating: yolov3-tf2-master/.gitignore
#   inflating: yolov3-tf2-master/LICENSE
#   inflating: yolov3-tf2-master/README.md
#    creating: yolov3-tf2-master/checkpoints/
#  extracting: yolov3-tf2-master/checkpoints/.gitkeep
#   inflating: yolov3-tf2-master/convert.py
#    creating: yolov3-tf2-master/data/
#   inflating: yolov3-tf2-master/data/checkpoint
#   inflating: yolov3-tf2-master/data/coco.names
#  extracting: yolov3-tf2-master/data/girl.png
#   inflating: yolov3-tf2-master/data/meme.jpg
#   inflating: yolov3-tf2-master/data/meme2.jpeg
#   inflating: yolov3-tf2-master/data/meme_out.jpg
#   inflating: yolov3-tf2-master/data/street.jpg
#   inflating: yolov3-tf2-master/data/street_out.jpg
#   inflating: yolov3-tf2-master/detect.py
#   inflating: yolov3-tf2-master/detect_video.py
#   inflating: yolov3-tf2-master/environment.yml
#   inflating: yolov3-tf2-master/export_tfserving.py
#  extracting: yolov3-tf2-master/requirements.txt
#   inflating: yolov3-tf2-master/train.py
#    creating: yolov3-tf2-master/yolov3_tf2/
#  extracting: yolov3-tf2-master/yolov3_tf2/__init__.py
#   inflating: yolov3-tf2-master/yolov3_tf2/batch_norm.py
#   inflating: yolov3-tf2-master/yolov3_tf2/dataset.py
#   inflating: yolov3-tf2-master/yolov3_tf2/models.py
#   inflating: yolov3-tf2-master/yolov3_tf2/utils.py

# %%
cd yolov3-tf2-master/
# Out:
# /content/yolov3-tf2-master

# %%
# !pip install -r requirements.txt
# Out:
# Collecting tensorflow-gpu==2.0.0a0 (from -r requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/1a/66/32cffad095253219d53f6b6c2a436637bbe45ac4e7be0244557210dc3918/tensorflow_gpu-2.0.0a0-cp36-cp36m-manylinux1_x86_64.whl (332.1MB)
#      |████████████████████████████████| 332.1MB 62kB/s
# Collecting opencv-python==4.0.0.21 (from -r requirements.txt (line 2))
#   Downloading https://files.pythonhosted.org/packages/37/49/874d119948a5a084a7ebe98308214098ef3471d76ab74200f9800efeef15/opencv_python-4.0.0.21-cp36-cp36m-manylinux1_x86_64.whl (25.4MB)
#      |████████████████████████████████| 25.4MB 43.1MB/s
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0a0->-r requirements.txt (line 1)) (0.33.4)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0a0->-r requirements.txt (line 1)) (1.0.8)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0a0->-r requirements.txt (line 1)) (0.8.0)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0a0->-r requirements.txt (line 1)) (1.16.4)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0a0->-r requirements.txt (line 1)) (1.1.0)
# Requirement already satisfied: google-pasta>=0.1.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0a0->-r requirements.txt (line 1)) (0.1.7)
# Collecting tb-nightly<1.14.0a20190302,>=1.14.0a20190301 (from tensorflow-gpu==2.0.0a0->-r requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/a9/51/aa1d756644bf4624c03844115e4ac4058eff77acd786b26315f051a4b195/tb_nightly-1.14.0a20190301-py3-none-any.whl (3.0MB)
#      |████████████████████████████████| 3.0MB 37.5MB/s
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0a0->-r requirements.txt (line 1)) (1.12.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0a0->-r requirements.txt (line 1)) (1.15.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0a0->-r requirements.txt (line 1)) (3.7.1)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0a0->-r requirements.txt (line 1)) (0.7.1)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0a0->-r requirements.txt (line 1)) (0.2.2)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0a0->-r requirements.txt (line 1)) (1.1.0)
# Collecting tf-estimator-nightly<1.14.0.dev2019030116,>=1.14.0.dev2019030115 (from tensorflow-gpu==2.0.0a0->-r requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/13/82/f16063b4eed210dc2ab057930ac1da4fbe1e91b7b051a6c8370b401e6ae7/tf_estimator_nightly-1.14.0.dev2019030115-py2.py3-none-any.whl (411kB)
#      |████████████████████████████████| 419kB 29.4MB/s
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow-gpu==2.0.0a0->-r requirements.txt (line 1)) (2.8.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<1.14.0a20190302,>=1.14.0a20190301->tensorflow-gpu==2.0.0a0->-r requirements.txt (line 1)) (3.1.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<1.14.0a20190302,>=1.14.0a20190301->tensorflow-gpu==2.0.0a0->-r requirements.txt (line 1)) (0.15.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow-gpu==2.0.0a0->-r requirements.txt (line 1)) (41.0.1)
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: tb-nightly, tf-estimator-nightly, tensorflow-gpu, opencv-python
#   Found existing installation: opencv-python 3.4.5.20
#     Uninstalling opencv-python-3.4.5.20:
#       Successfully uninstalled opencv-python-3.4.5.20
# Successfully installed opencv-python-4.0.0.21 tb-nightly-1.14.0a20190301 tensorflow-gpu-2.0.0a0 tf-estimator-nightly-1.14.0.dev2019030115

# %%
# !wget https://pjreddie.com/media/files/yolov3-tiny.weights -O data/yolov3-tiny.weights
# !python convert.py --weights ./data/yolov3-tiny.weights --output ./checkpoints/yolov3-tiny.tf --tiny
# Out:
# --2019-07-08 11:59:26--  https://pjreddie.com/media/files/yolov3-tiny.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35434956 (34M) [application/octet-stream]
# Saving to: ‘data/yolov3-tiny.weights’
#
# data/yolov3-tiny.we 100%[===================>]  33.79M  28.1MB/s    in 1.2s
#
# 2019-07-08 11:59:28 (28.1 MB/s) - ‘data/yolov3-tiny.weights’ saved [35434956/35434956]
#
# 2019-07-08 11:59:32.120179: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-07-08 11:59:32.160473: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcuda.so.1
# 2019-07-08 11:59:32.279705: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2019-07-08 11:59:32.279839: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:153] kernel driver does not appear to be running on this host (b9d6ee798281): /proc/driver/nvidia/version does not exist
# 2019-07-08 11:59:32.283141: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-07-08 11:59:32.283466: I tensorflow/compiler/xla/service/service.cc:162] XLA service 0x2b32680 executing computations on platform Host. Devices:
# 2019-07-08 11:59:32.283511: I tensorflow/compiler/xla/service/service.cc:169]   StreamExecutor device (0): <undefined>, <undefined>
# Model: "yolov3_tiny"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# yolo_darknet (Model)            ((None, None, None,  6298480     input_1[0][0]
# __________________________________________________________________________________________________
# yolo_conv_0 (Model)             (None, None, None, 2 263168      yolo_darknet[1][1]
# __________________________________________________________________________________________________
# yolo_conv_1 (Model)             (None, None, None, 3 33280       yolo_conv_0[1][0]
#                                                                  yolo_darknet[1][0]
# __________________________________________________________________________________________________
# yolo_output_0 (Model)           (None, None, None, 3 1312511     yolo_conv_0[1][0]
# __________________________________________________________________________________________________
# yolo_output_1 (Model)           (None, None, None, 3 951295      yolo_conv_1[1][0]
# __________________________________________________________________________________________________
# yolo_boxes_0 (Lambda)           ((None, None, None,  0           yolo_output_0[1][0]
# __________________________________________________________________________________________________
# yolo_boxes_1 (Lambda)           ((None, None, None,  0           yolo_output_1[1][0]
# __________________________________________________________________________________________________
# yolo_nms (Lambda)               ((None, 100, 4), (No 0           yolo_boxes_0[0][0]
#                                                                  yolo_boxes_0[0][1]
#                                                                  yolo_boxes_0[0][2]
#                                                                  yolo_boxes_1[0][0]
#                                                                  yolo_boxes_1[0][1]
#                                                                  yolo_boxes_1[0][2]
# ==================================================================================================
# Total params: 8,858,734
# Trainable params: 8,852,366
# Non-trainable params: 6,368
# __________________________________________________________________________________________________
# I0708 11:59:34.126930 139971231537024 convert.py:18] model created
# I0708 11:59:34.127771 139971231537024 utils.py:45] yolo_darknet/conv2d bn
# I0708 11:59:34.129689 139971231537024 utils.py:45] yolo_darknet/conv2d_1 bn
# I0708 11:59:34.131243 139971231537024 utils.py:45] yolo_darknet/conv2d_2 bn
# I0708 11:59:34.132746 139971231537024 utils.py:45] yolo_darknet/conv2d_3 bn
# I0708 11:59:34.134670 139971231537024 utils.py:45] yolo_darknet/conv2d_4 bn
# I0708 11:59:34.138530 139971231537024 utils.py:45] yolo_darknet/conv2d_5 bn
# I0708 11:59:34.149278 139971231537024 utils.py:45] yolo_darknet/conv2d_6 bn
# I0708 11:59:34.233040 139971231537024 utils.py:45] yolo_conv_0/conv2d_7 bn
# I0708 11:59:34.238068 139971231537024 utils.py:45] yolo_output_0/conv2d_8 bn
# I0708 11:59:34.249186 139971231537024 utils.py:45] yolo_output_0/conv2d_9 bias
# I0708 11:59:34.251286 139971231537024 utils.py:45] yolo_conv_1/conv2d_10 bn
# I0708 11:59:34.252894 139971231537024 utils.py:45] yolo_output_1/conv2d_11 bn
# I0708 11:59:34.261284 139971231537024 utils.py:45] yolo_output_1/conv2d_12 bias
# I0708 11:59:34.262712 139971231537024 convert.py:21] weights loaded
# I0708 11:59:34.470067 139971231537024 convert.py:25] sanity check passed
# I0708 11:59:34.569612 139971231537024 convert.py:28] weights saved

# %%
# yolov3-tiny
# !python detect.py --weights ./checkpoints/yolov3-tiny.tf --tiny --image ./data/street.jpg
# Out:
# 2019-07-08 11:59:38.978894: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-07-08 11:59:38.984697: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcuda.so.1
# 2019-07-08 11:59:38.992270: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2019-07-08 11:59:38.992344: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:153] kernel driver does not appear to be running on this host (b9d6ee798281): /proc/driver/nvidia/version does not exist
# 2019-07-08 11:59:38.994632: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-07-08 11:59:38.994893: I tensorflow/compiler/xla/service/service.cc:162] XLA service 0x1d38680 executing computations on platform Host. Devices:
# 2019-07-08 11:59:38.994928: I tensorflow/compiler/xla/service/service.cc:169]   StreamExecutor device (0): <undefined>, <undefined>
# I0708 11:59:41.105470 139957606512512 detect.py:29] weights loaded
# I0708 11:59:41.105992 139957606512512 detect.py:32] classes loaded
# I0708 11:59:41.428767 139957606512512 detect.py:41] time: 0.28445887565612793
# I0708 11:59:41.428990 139957606512512 detect.py:43] detections:
# I0708 11:59:41.430310 139957606512512 detect.py:47] 	car, 0.915712833404541, [0.29890415 0.38086182 0.36064854 0.5202759 ]
# I0708 11:59:41.431233 139957606512512 detect.py:47] 	bus, 0.90668785572052, [0.36375186 0.15101331 0.62805045 0.50172883]
# I0708 11:59:41.432097 139957606512512 detect.py:47] 	bus, 0.6741605997085571, [0.671885   0.19172344 0.97814786 0.54268146]
# I0708 11:59:41.432945 139957606512512 detect.py:47] 	car, 0.616561233997345, [0.24638589 0.35268342 0.39559376 0.5378101 ]
# I0708 11:59:41.433779 139957606512512 detect.py:47] 	person, 0.5871638655662537, [0.24246435 0.40669447 0.27136987 0.48467493]
# I0708 11:59:41.498541 139957606512512 detect.py:52] output saved to: ./output.jpg
